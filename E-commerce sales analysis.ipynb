# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Display Top 2 Rows of The Dataset

# %%
dataset = pd.read_csv('Superstore.csv')
dataset.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101  5/28/2012  5/30/2012
# 1     West        Washington  Anacortes        98221   7/7/2010   7/8/2010
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %% [markdown]
# # Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
dataset.shape
# Out:
# (9426, 24)

# %% [markdown]
# # check null value in dataset

# %%
# find missing values

dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# # fill value in datasets using fillna() method.

# %%
# fill mean values in particular column of datasets

dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(),inplace = True)

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# # find  counts value inside order priority

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %% [markdown]
# # Order priority

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
dataset['Order Priority'] = dataset['Order Priority'].replace("Critical ","Critical")

# %% [markdown]
#  #  visualization of order priority using histplot

# %%
# to make a graph for visualization

plt.figure(figsize =(8,4))   #(width and Height),facecolor="cyan"
plt.title("Count of Order Priority", color='red',fontsize=20)
sns.histplot(x="Order Priority", data =dataset, color='green')
plt.savefig("Count of Order Priority.jpg")

plt.show()

# %%
dataset.shape
# Out:
# (9426, 24)

# %% [markdown]
# # values count of  Ship mode

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %% [markdown]
# # find index name of shiping mode and store in x variable

# %%
# find index name of shiping mode

dataset["Ship Mode"].value_counts().index
# Out:
# Index(['Regular Air', 'Delivery Truck', 'Express Air'], dtype='object', name='Ship Mode')

# %%
x = dataset["Ship Mode"].value_counts().index

# %% [markdown]
# # find values of ship mode and store in y variable

# %%
# dataset['Ship Mode'].value_counts().values

y = dataset['Ship Mode'].value_counts().values

# %% [markdown]
# #  labels are controlling the text elements for visualizations and including axes labels.

# %%
plt.figure(figsize =(8,4))   #(width and Height)
plt.title("Count of Ship Mode", color='red')

plt.pie(y,   labels= x, startangle = 45, autopct = "%0.2f%%", colors =["deeppink","yellow","blue"])
plt.legend(loc=3)
plt.show()

# %%
dataset.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101  5/28/2012  5/30/2012
# 1     West        Washington  Anacortes        98221   7/7/2010   7/8/2010
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %% [markdown]
# # Ship mode VS Product Category

# %%
sns.countplot(x = 'Ship Mode', data= dataset, hue="Product Category") #hue parameter is use for defferenciate of items.
plt.show()

# %%
plt.figure(figsize = (8,4))
sns.countplot(x = 'Customer Segment', data= dataset) 
plt.show()

# %% [markdown]
# # product category vs Product Sub-Category

# %%
plt.figure(figsize = (8,4))
sns.countplot(x = 'Product Category', data=dataset,hue="Product Sub-Category") 
plt.show()

# %%
plt.figure(figsize = (10,4))
sns.countplot(x = 'Product Category', data=dataset[dataset["Product Category"]=="Office Supplies"],hue="Product Sub-Category") 
plt.show()

# %%
dataset.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %% [markdown]
# # Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
sns.barplot(x= 'Product Category', y = 'Profit', data=dataset,estimator = 'sum')
plt.show()

# %%
dataset['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
sns.barplot(x= 'Product Category', y = 'Product Base Margin', data=dataset,estimator = 'sum')
plt.show()
